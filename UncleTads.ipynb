# %%
import numpy as np
import pandas as pd
df = pd.read_csv('final_phone_preferences_india.csv')
df.shape
# Out:
# (100000, 19)

# %%
df = pd.read_csv('final_phone_preferences_india.csv')
print("Data loaded successfully!")
# Out:
# Data loaded successfully!

# %%
print(df.head())
# Out:
#    Age  Gender       City Income Level    Brand            Model Payment Mode  \
# 0   65   Other    Chennai       6L-10L   iPhone        iPhone 13  Credit Card
# 1   65  Female    Chennai          <3L  Android  Samsung Model 2          EMI
# 2   30   Other     Jaipur          <3L  Android  OnePlus Model 8   Debit Card
# 3   52    Male    Lucknow         20L+   iPhone        iPhone 11   Debit Card
# 4   40  Female  Hyderabad       6L-10L   iPhone        iPhone 13         Cash
#
#   Purchase Platform  Screen Time (hrs)  Data Consumption (GB) Preferred App  \
# 0           Offline                9.1                    7.0      LinkedIn
# 1            Online                2.5                    2.8       YouTube
# 2           Offline                4.1                   26.5      LinkedIn
# 3            Online                4.9                   34.2      Facebook
# 4           Offline                8.5                    4.6      Snapchat
#
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (100000, 19)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Age                    100000 non-null  int64
#  1   Gender                 100000 non-null  object
#  2   City                   100000 non-null  object
#  3   Income Level           100000 non-null  object
#  4   Brand                  100000 non-null  object
#  5   Model                  100000 non-null  object
#  6   Payment Mode           100000 non-null  object
#  7   Purchase Platform      100000 non-null  object
#  8   Screen Time (hrs)      100000 non-null  float64
#  9   Data Consumption (GB)  100000 non-null  float64
#  10  Preferred App          100000 non-null  object
#  11  Rating                 100000 non-null  int64
#  12  Purchase Reason        100000 non-null  object
#  13  Storage (GB)           100000 non-null  int64
# ...

# %%
print(df.columns)
print(df.describe())
# Out:
# Index(['Age', 'Gender', 'City', 'Income Level', 'Brand', 'Model',
#        'Payment Mode', 'Purchase Platform', 'Screen Time (hrs)',
#        'Data Consumption (GB)', 'Preferred App', 'Rating', 'Purchase Reason',
#        'Storage (GB)', 'RAM (GB)', 'Battery (mAh)', 'Dual SIM',
#        'Purchase Month', 'Price (INR)'],
#       dtype='object')
#                  Age  Screen Time (hrs)  Data Consumption (GB)         Rating  \
# count  100000.000000      100000.000000          100000.000000  100000.000000
# mean       41.842890           6.001024              26.015189       2.999380
# std        15.351868           2.308244              13.863733       1.417039
# min        22.000000           2.000000               2.000000       1.000000
# 25%        30.000000           4.000000              14.000000       2.000000
# 50%        40.000000           6.000000              26.100000       3.000000
# 75%        52.000000           8.000000              38.000000       4.000000
# ...

# %%
print(df.tail())
# Out:
#        Age  Gender     City Income Level    Brand                 Model  \
# 99995   30   Other     Pune         20L+  Android  Google Pixel Model 9
# 99996   30   Other    Delhi      10L-20L   iPhone             iPhone 13
# 99997   22   Other  Chennai      10L-20L   iPhone             iPhone 15
# 99998   30    Male  Lucknow         20L+  Android        Xiaomi Model 8
# 99999   22  Female  Lucknow          <3L   iPhone             iPhone 14
#
#       Payment Mode Purchase Platform  Screen Time (hrs)  \
# 99995          UPI           Offline                9.3
# 99996          EMI           Offline                8.6
# 99997          EMI           Offline                5.3
# 99998          UPI            Online                6.4
# 99999          UPI            Online                4.2
#
#        Data Consumption (GB) Preferred App  Rating Purchase Reason  \
# 99995                   12.1       YouTube       4     Performance
# ...

# %%
data_types = df.dtypes

# %%
print("data types of each attribute")
print(data_types)
# Out:
# data types of each attribute
# Age                        int64
# Gender                    object
# City                      object
# Income Level              object
# Brand                     object
# Model                     object
# Payment Mode              object
# Purchase Platform         object
# Screen Time (hrs)        float64
# Data Consumption (GB)    float64
# Preferred App             object
# Rating                     int64
# Purchase Reason           object
# Storage (GB)               int64
# RAM (GB)                   int64
# Battery (mAh)              int64
# Dual SIM                  object
# Purchase Month            object
# Price (INR)                int64
# dtype: object

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
df =pd.read_csv('final_phone_preferences_india.csv')

# %%
#define the attributes
x_attribute = 'Purchase Month'
y_attribute = 'Price'

#Reshape the data
x = df[[x_attribute]].values
y = df[[y_attribute]].values

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue'
, alpha=0.5, label='Data Points')
• Plot the regression Line plt. plot(X, y, color='red'
, label='Regression Line')
# Add Labels and title
pit. xlabel(x_attribute)
plt. ylabel(y_attribute)
plt. title( 'Linear Regression of (J vs t}'
•format (y_attribute, x_attribute))
plt. legend() # Show Legend
plt. grid(True) # Add grid for better readability
# Show the plot
plt. tight_layout()
ply.show()
# Out:
#   Cell In[33], line 5
#     • Plot the regression Line plt. plot(X, y, color='red'
#     ^
# SyntaxError: invalid character '•' (U+2022)
